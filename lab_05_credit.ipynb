# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
fig, axs = plt.subplots(5, 3)

# %%
df = pd.read_csv('Credit.csv')
df.head(5)
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
# 3           4  148.924   9504     681      3   36         11  Female      No
# 4           5   55.882   4897     357      2   68         16    Male      No
#
#   Married  Ethnicity  Balance
# 0     Yes  Caucasian      333
# 1     Yes      Asian      903
# 2      No      Asian      580
# 3      No      Asian      964
# 4     Yes  Caucasian      331

# %%
df.describe()
# Out:
#        Unnamed: 0      Income         Limit      Rating       Cards  \
# count  400.000000  400.000000    400.000000  400.000000  400.000000
# mean   200.500000   45.218885   4735.600000  354.940000    2.957500
# std    115.614301   35.244273   2308.198848  154.724143    1.371275
# min      1.000000   10.354000    855.000000   93.000000    1.000000
# 25%    100.750000   21.007250   3088.000000  247.250000    2.000000
# 50%    200.500000   33.115500   4622.500000  344.000000    3.000000
# 75%    300.250000   57.470750   5872.750000  437.250000    4.000000
# max    400.000000  186.634000  13913.000000  982.000000    9.000000
#
#               Age   Education      Balance
# count  400.000000  400.000000   400.000000
# mean    55.667500   13.450000   520.015000
# std     17.249807    3.125207   459.758877
# min     23.000000    5.000000     0.000000
# 25%     41.750000   11.000000    68.750000
# 50%     56.000000   14.000000   459.500000
# 75%     70.000000   16.000000   863.000000
# ...

# %% [markdown]
# # Checking Income vs Limit

# %%
sns.scatterplot(x='Income', y='Limit', data=df)

# %%
sns.residplot(x='Income', y='Limit', data=df)

# %%
model = LinearRegression()
model.fit(X=df[['Income']], y=df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_, model.intercept_
# Out:
# (array([[51.8750206]]), array([2389.86940892]))

# %%
result = f"y = {model.coef_[0][0]} x + {model.intercept_[0]}"
result
# Out:
# 'y = 51.875020604432734 x + 2389.8694089155265'

# %%
X = df[['Income']]
y = df[['Limit']]


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_, model.intercept_
# Out:
# (array([[54.65307786]]), array([2252.61537117]))

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print('RMSE:', np.sqrt(mse))
# Out:
# RMSE: 1364.5365761342146

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.scatter(X_test, y_pred, color='green')
plt.show()

# %% [markdown]
# # Checking Rating vs Limit

# %%
sns.scatterplot(x='Rating', y='Limit', data=df)

# %%
sns.residplot(x='Rating', y='Limit', data=df)

# %%
model = LinearRegression()
model.fit(X=df[['Rating']], y=df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_, model.intercept_
# Out:
# (array([[14.87160712]]), array([-542.92822999]))

# %%
result = f"y = {model.coef_[0][0]} x + {model.intercept_[0]}"
result
# Out:
# 'y = 14.871607116658868 x + -542.9282299868983'

# %%
X = df[['Rating']]
y = df[['Limit']]


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_, model.intercept_
# Out:
# (array([[14.87994415]]), array([-549.15608218]))

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print('RMSE:', np.sqrt(mse))
# Out:
# RMSE: 164.6319022156034

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.scatter(X_test, y_pred, color='green')
plt.show()

# %% [markdown]
# # Checking Cards vs Limit

# %%
sns.scatterplot(x='Cards', y='Limit', data=df)

# %%
sns.residplot(x='Cards', y='Limit', data=df)

# %%
model = LinearRegression()
model.fit(X=df[['Cards']], y=df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_, model.intercept_
# Out:
# (array([[17.22189457]]), array([4684.66624682]))

# %%
result = f"y = {model.coef_[0][0]} x + {model.intercept_[0]}"
result
# Out:
# 'y = 17.221894565677392 x + 4684.666246822009'

# %%
X = df[['Cards']]
y = df[['Limit']]


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_, model.intercept_
# Out:
# (array([[30.03835045]]), array([4636.0593404]))

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print('RMSE:', np.sqrt(mse))
# Out:
# RMSE: 1905.4446551712351

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.scatter(X_test, y_pred, color='green')
plt.show()

# %% [markdown]
# # Checking Age vs Limit

# %%
sns.scatterplot(x='Age', y='Limit', data=df)

# %%
sns.residplot(x='Age', y='Limit', data=df)

# %%
model = LinearRegression()
model.fit(X=df[['Age']], y=df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_, model.intercept_
# Out:
# (array([[13.49982568]]), array([3984.09845403]))

# %%
result = f"y = {model.coef_[0][0]} x + {model.intercept_[0]}"
result
# Out:
# 'y = 13.499825678763637 x + 3984.0984540274258'

# %%
X = df[['Age']]
y = df[['Limit']]


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_, model.intercept_
# Out:
# (array([[15.31954412]]), array([3857.64353732]))

# %%
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print('RMSE:', np.sqrt(mse))
# Out:
# RMSE: 1905.4158649725307

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.scatter(X_test, y_pred, color='green')
plt.show()

# %% [markdown]
# # Checking Eductaion vs Limit

# %%
sns.scatterplot(x='Education', y='Limit', data=df)

# %%
sns.residplot(x='Education', y='Limit', data=df)

# %%
model = LinearRegression()
model.fit(X=df[['Education']], y=df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_, model.intercept_
# Out:
# (array([[-17.39235309]]), array([4969.52714909]))

# %%
result = f"y = {model.coef_[0][0]} x + {model.intercept_[0]}"
result
# Out:
# 'y = -17.392353092122143 x + 4969.527149089043'

# %%
X = df[['Education']]
y = df[['Limit']]


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_, model.intercept_
# Out:
# (array([[-18.64489536]]), array([4976.1422736]))

# %%
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print('RMSE:', np.sqrt(mse))
# Out:
# RMSE: 1903.741398844263

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.scatter(X_test, y_pred, color='green')
plt.show()
